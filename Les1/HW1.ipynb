# %% [markdown]
# ### Домашнее задание <a class="anchor" id="hw"></a><center>

# %% [markdown]
# 1. Подберите скорость обучения (eta) и количество итераций

# %%
import numpy as np

# %%
def calc_mse(y, y_pred):
    err = np.mean((y - y_pred)**2)
    return err

# %%
X = np.array([[ 1,  1],
              [ 1,  1],
              [ 1,  2],
              [ 1,  5],
              [ 1,  3],
              [ 1,  0],
              [ 1,  5],
              [ 1, 10],
              [ 1,  1],
              [ 1,  2]])
y = [45, 55, 50, 55, 60, 35, 75, 80, 50, 60]

# %%
n = X.shape[0]

rates = [0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1]
n_iter = 100
for eta in rates:
    
    W = np.array([1, 0.5])
    print(f'\n\nNumber of objects = {n} \
           \nLearning rate = {eta} \
           \nInitial weights = {W} \n')

    for i in range(n_iter):
        y_pred = np.dot(X, W)
        err = calc_mse(y, y_pred)
        for k in range(W.shape[0]):
            W[k] -= eta * (1/n * 2 * X[:, k] @ (y_pred - y))
        if i % 10 == 0:
            eta /= 1.1
            print(f'Iteration #{i}: W_new = {W}, MSE = {round(err, 2)}')
# Out:
# Number of objects = 10
# Learning rate = 0.0001
# Initial weights = [1.  0.5]
#
# Iteration #0: W_new = [1.0108 0.5377], MSE = 3047.75
# Iteration #10: W_new = [1.10784583 0.87425489], MSE = 2910.74
# Iteration #20: W_new = [1.19433808 1.17081028], MSE = 2793.57
# Iteration #30: W_new = [1.27157753 1.43285993], MSE = 2692.81
# Iteration #40: W_new = [1.34067642 1.66501505], MSE = 2605.72
# Iteration #50: W_new = [1.40259086 1.87116766], MSE = 2530.09
# Iteration #60: W_new = [1.45814668 2.05462009], MSE = 2464.14
# Iteration #70: W_new = [1.50806047 2.21818819], MSE = 2406.41
# Iteration #80: W_new = [1.55295649 2.36428416], MSE = 2355.7
# Iteration #90: W_new = [1.59338065 2.49498341], MSE = 2311.02
#
#
# Number of objects = 10
# Learning rate = 0.0005
# Initial weights = [1.  0.5]
#
# Iteration #0: W_new = [1.054  0.6885], MSE = 3047.75
# Iteration #10: W_new = [1.51756012 2.25361947], MSE = 2439.04
# Iteration #20: W_new = [1.90070677 3.46897648], MSE = 2032.1
# ...

# %% [markdown]
# **Минимум где-то в районе скорости 0.05**

# %%
n = X.shape[0]

rates = np.linspace(0.01, 0.1, 10)
n_iter = 100
for eta in rates:
    
    W = np.array([1, 0.5])
    print(f'\n\nNumber of objects = {n} \
           \nLearning rate = {eta} \
           \nInitial weights = {W} \n')

    for i in range(n_iter):
        y_pred = np.dot(X, W)
        err = calc_mse(y, y_pred)
        for k in range(W.shape[0]):
            W[k] -= eta * (1/n * 2 * X[:, k] @ (y_pred - y))
        if i % 10 == 0:
            eta /= 1.1
            print(f'Iteration #{i}: W_new = {W}, MSE = {round(err, 2)}')
# Out:
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [1.  0.5]
#
# Iteration #0: W_new = [2.08 4.27], MSE = 3047.75
# Iteration #10: W_new = [ 6.67106886 10.61676385], MSE = 749.71
# Iteration #20: W_new = [ 9.49320908 10.25731657], MSE = 648.91
# Iteration #30: W_new = [11.85740092  9.83349244], MSE = 570.46
# Iteration #40: W_new = [13.86876921  9.46898661], MSE = 508.03
# Iteration #50: W_new = [15.59085668  9.15672679], MSE = 457.73
# Iteration #60: W_new = [17.07337653  8.88789585], MSE = 416.77
# Iteration #70: W_new = [18.35601294  8.65530964], MSE = 383.06
# Iteration #80: W_new = [19.47073522  8.45317196], MSE = 355.08
# Iteration #90: W_new = [20.44350656  8.27677488], MSE = 331.65
#
#
# Number of objects = 10
# Learning rate = 0.020000000000000004
# Initial weights = [1.  0.5]
#
# Iteration #0: W_new = [3.16 8.04], MSE = 3047.75
# Iteration #10: W_new = [10.11260987 10.14999331], MSE = 638.84
# Iteration #20: W_new = [15.03767942  9.25703826], MSE = 481.66
# ...

# %% [markdown]
# **0.09 - самый минимальный результат**

# %%
n = X.shape[0]

eta = 0.09
n_iter = 100

W = np.array([1, 0.5])
print(f'Number of objects = {n} \
       \nLearning rate = {eta} \
       \nInitial weights = {W} \n')

for i in range(n_iter):
    y_pred = np.dot(X, W)
    err = calc_mse(y, y_pred)
    for k in range(W.shape[0]):
        W[k] -= eta * (1/n * 2 * X[:, k] @ (y_pred - y))
    if i % 10 == 0:
        eta /= 1.1
        print(f'Iteration #{i}: W_new = {W}, MSE = {round(err, 2)}')
# Out:
# Number of objects = 10
# Learning rate = 0.09
# Initial weights = [1.  0.5]
#
# Iteration #0: W_new = [10.72 34.43], MSE = 3047.75
# Iteration #10: W_new = [ 2276.33841618 12409.86650201], MSE = 796432997.11
# Iteration #20: W_new = [ 262978.48744009 1450044.52016754], MSE = 14701686451429.94
# Iteration #30: W_new = [ 6241364.00818315 34418831.70511374], MSE = 1.1394319142061614e+16
# Iteration #40: W_new = [2.68067569e+07 1.47830133e+08], MSE = 2.9587757272246586e+17
# Iteration #50: W_new = [17974890.99340409 99125318.78568712], MSE = 1.9286985343530534e+17
# Iteration #60: W_new = [1548373.20234155 8538524.8275565 ], MSE = 2157273408111653.5
# Iteration #70: W_new = [13147.39827568 72262.4199961 ], MSE = 245728807162.94
# Iteration #80: W_new = [52.0124153  44.55961881], MSE = 133904.39
# Iteration #90: W_new = [44.76446079  3.86739348], MSE = 44.01

# %%
n = X.shape[0]

eta = 0.09
n_iter = 200

W = np.array([1, 0.5])
print(f'Number of objects = {n} \
       \nLearning rate = {eta} \
       \nInitial weights = {W} \n')

for i in range(n_iter):
    y_pred = np.dot(X, W)
    err = calc_mse(y, y_pred)
    for k in range(W.shape[0]):
        W[k] -= eta * (1/n * 2 * X[:, k] @ (y_pred - y))
    if i % 10 == 0:
        eta /= 1.1
        print(f'Iteration #{i}: W_new = {W}, MSE = {round(err, 2)}')
# Out:
# Number of objects = 10
# Learning rate = 0.09
# Initial weights = [1.  0.5]
#
# Iteration #0: W_new = [10.72 34.43], MSE = 3047.75
# Iteration #10: W_new = [ 2276.33841618 12409.86650201], MSE = 796432997.11
# Iteration #20: W_new = [ 262978.48744009 1450044.52016754], MSE = 14701686451429.94
# Iteration #30: W_new = [ 6241364.00818315 34418831.70511374], MSE = 1.1394319142061614e+16
# Iteration #40: W_new = [2.68067569e+07 1.47830133e+08], MSE = 2.9587757272246586e+17
# Iteration #50: W_new = [17974890.99340409 99125318.78568712], MSE = 1.9286985343530534e+17
# Iteration #60: W_new = [1548373.20234155 8538524.8275565 ], MSE = 2157273408111653.5
# Iteration #70: W_new = [13147.39827568 72262.4199961 ], MSE = 245728807162.94
# Iteration #80: W_new = [52.0124153  44.55961881], MSE = 133904.39
# Iteration #90: W_new = [44.76446079  3.86739348], MSE = 44.01
# Iteration #100: W_new = [44.84630987  3.85170275], MSE = 43.99
# Iteration #110: W_new = [44.90104023  3.84177824], MSE = 43.98
# ...

# %% [markdown]
# **После 100 итерации результат не сильно меняется. Причём если уменьшать скорость обучения не очень часто, модель получится бестолковая, быстро пойдёт в разнос (эксперимент ниже, уменьшаем eta каждые 100 итераций вместо 10) и потом уже не доучится**

# %%
n = X.shape[0]

eta = 0.09
n_iter = 1000

W = np.array([1, 0.5])
print(f'Number of objects = {n} \
       \nLearning rate = {eta} \
       \nInitial weights = {W} \n')

for i in range(n_iter):
    y_pred = np.dot(X, W)
    err = calc_mse(y, y_pred)
    for k in range(W.shape[0]):
        W[k] -= eta * (1/n * 2 * X[:, k] @ (y_pred - y))
    if i % 100 == 0:
        eta /= 1.1
        print(f'Iteration #{i}: W_new = {W}, MSE = {round(err, 2)}')
# Out:
# Number of objects = 10
# Learning rate = 0.09
# Initial weights = [1.  0.5]
#
# Iteration #0: W_new = [10.72 34.43], MSE = 3047.75
# Iteration #100: W_new = [6.84284079e+27 3.77359946e+28], MSE = 7.372575504838603e+57
# Iteration #200: W_new = [3.26457088e+48 1.80030243e+49], MSE = 2.266202207564907e+99
# Iteration #300: W_new = [1.85348724e+62 1.02213666e+63], MSE = 1.0048799494117009e+127
# Iteration #400: W_new = [3.95966531e+68 2.18362392e+69], MSE = 6.455677508366033e+139
# Iteration #500: W_new = [7.27569915e+66 4.01230646e+67], MSE = 3.1599731110716617e+136
# Iteration #600: W_new = [1.63627165e+56 9.02349398e+56], MSE = 2.409291634801751e+115
# Iteration #700: W_new = [ 1.89413462e+47 -3.43472110e+46], MSE = 1.841667648845675e+94
# Iteration #800: W_new = [ 3.81765283e+45 -6.92272479e+44], MSE = 7.421936475390933e+90
# Iteration #900: W_new = [ 1.10431686e+44 -2.00250835e+43], MSE = 6.165574340789715e+87

# %% [markdown]
# 2*. В этом коде мы избавляемся от итераций по весам, но тут есть ошибка, исправьте ее

# %% [markdown]
# **Нужно было транспонировать матрицу Х (по формуле + размерности не подходили для умножения)<br>
# P.S. Только результат почему-то все равно получается отличный от исходного :(**

# %%
n = X.shape[0]

eta = 1e-2 
n_iter = 100

W = np.array([1, 0.5])
print(f'Number of objects = {n} \
       \nLearning rate = {eta} \
       \nInitial weights = {W} \n')

for i in range(n_iter):
    y_pred = np.dot(X, W)
    err = calc_mse(y, y_pred)
#     for k in range(W.shape[0]):
#         W[k] -= eta * (1/n * 2 * X[:, k] @ (y_pred - y))
    # ИЗМЕНЕНИЯ
    W -= eta * (1/n * 2 * np.dot(X.T, y_pred - y)) #Нужно было транспонировать матрицу Х, размерности не подходили для умножения
    # ИЗМЕНЕНИЯ
    #
    if i % 10 == 0:
        print(f'Iteration #{i}: W_new = {W}, MSE = {round(err,2)}')
# Out:
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [1.  0.5]
#
# Iteration #0: W_new = [2.08 4.27], MSE = 3047.75
# Iteration #10: W_new = [ 7.0011236 10.6169007], MSE = 738.65
# Iteration #20: W_new = [10.3486292  10.10603105], MSE = 622.03
# Iteration #30: W_new = [13.38789582  9.55618391], MSE = 525.24
# Iteration #40: W_new = [16.16088505  9.05336203], MSE = 444.66
# Iteration #50: W_new = [18.69110735  8.59454545], MSE = 377.58
# Iteration #60: W_new = [20.99981865  8.17589626], MSE = 321.72
# Iteration #70: W_new = [23.10641138  7.79389815], MSE = 275.22
# Iteration #80: W_new = [25.02858024  7.44534246], MSE = 236.5
# Iteration #90: W_new = [26.78247081  7.12730145], MSE = 204.27

# %%
#Исходный код с иетрациями по весам
n = X.shape[0]

eta = 1e-2 
n_iter = 100

W = np.array([1, 0.5])
print(f'Number of objects = {n} \
       \nLearning rate = {eta} \
       \nInitial weights = {W} \n')

for i in range(n_iter):
    y_pred = np.dot(X, W)
    err = calc_mse(y, y_pred)
    for k in range(W.shape[0]):
        W[k] -= eta * (1/n * 2 * X[:, k] @ (y_pred - y))
    if i % 10 == 0:
        eta /= 1.1
        print(f'Iteration #{i}: W_new = {W}, MSE = {round(err, 2)}')
# Out:
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [1.  0.5]
#
# Iteration #0: W_new = [2.08 4.27], MSE = 3047.75
# Iteration #10: W_new = [ 6.67106886 10.61676385], MSE = 749.71
# Iteration #20: W_new = [ 9.49320908 10.25731657], MSE = 648.91
# Iteration #30: W_new = [11.85740092  9.83349244], MSE = 570.46
# Iteration #40: W_new = [13.86876921  9.46898661], MSE = 508.03
# Iteration #50: W_new = [15.59085668  9.15672679], MSE = 457.73
# Iteration #60: W_new = [17.07337653  8.88789585], MSE = 416.77
# Iteration #70: W_new = [18.35601294  8.65530964], MSE = 383.06
# Iteration #80: W_new = [19.47073522  8.45317196], MSE = 355.08
# Iteration #90: W_new = [20.44350656  8.27677488], MSE = 331.65

# %% [markdown]
# 3*. Вместо того, чтобы задавать количество итераций, задайте другое условие останова алгоритма - когда веса перестают изменяться меньше определенного порога $\epsilon$.

# %% [markdown]
# **Будет дополнено до 23:59мск 17.02.2023**
